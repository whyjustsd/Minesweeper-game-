# %% [markdown]
# <a href="https://colab.research.google.com/github/whyjustsd/Minesweeper-game-/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
exp_data = pd.read_csv('/content/normalised-data.csv')

# %%
exp_data
# Out:
#       Tensile Stress(Mpa)    Load(N)  Tensile Strain(%)  Elongation(mm)
# 0                4.738170   132.6323          -0.010926       -0.002731
# 1                5.063530   141.7398          -0.004536       -0.001134
# 2                4.922569   137.7940          -0.010401       -0.002600
# 3                5.190864   145.3042           0.000334        0.000083
# 4                5.526020   154.6860          -0.006217       -0.001554
# ...                   ...        ...                ...             ...
# 2112           339.288100  9497.4520          31.693740        7.923436
# 2113           331.242600  9272.2420          31.716360        7.929090
# 2114           318.341500  8911.1090          31.634760        7.908690
# 2115           273.329300  7651.1140          31.632200        7.908049
# 2116           183.945000  5149.0430          31.538490        7.884622
#
# [2117 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
from matplotlib import pyplot as plt
exp_data.plot(kind='scatter',x='Tensile Strain(%)', y='Tensile Stress(Mpa)', s=16, alpha=.6)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
exp_data.plot(kind='scatter',x='Elongation(mm)', y='Load(N)', s=16, alpha=.6)
plt.gca().spines[['top', 'right',]].set_visible(False)
